# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
bands = np.loadtxt('bands.txt')

# %%
bands[30]
# Out:
# array([-2.15128279, -1.75128269,  1.75128376,  2.1512835 ])

# %%
for i in range(402):
    bands[i] = (bands[i+1] - bands[i])/0.10018
    i = i+1

# %%
bands[30]
# Out:
# array([-0.6776985 , -0.6776985 ,  0.67769374,  0.67769374])

# %%
bands.shape
# Out:
# (403, 4)

# %%
bands = bands.T

# %%
plt.plot(bands[0])
plt.plot(bands[1])
plt.plot(bands[2])
plt.plot(bands[3])

# %%
np.savetxt("velocity.txt", bands.T)
